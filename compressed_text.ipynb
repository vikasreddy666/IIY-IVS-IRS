# %% [markdown]
# <a href="https://colab.research.google.com/github/vikasreddy666/IIY-IVS-IRS/blob/main/compressed_text.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def compress(text):
    if not text:
        return ""
    compressed = ""
    count = 1
    for i in range(1, len(text)):
        if text[i] == text[i - 1]:
            count += 1
        else:
            compressed += text[i - 1] + str(count)
            count = 1
    compressed += text[-1] + str(count)
    return compressed


import os
if not os.path.exists("input.txt"):
    with open("input.txt", "w") as f:
        f.write("aaabbbbcc")


with open("input.txt", "r") as f:
    data = f.read().strip()


compressed_data = compress(data)


with open("compressed.txt", "w") as f:
    f.write(compressed_data)


print("Original:", data)
print("Compressed:", compressed_data)
# Out:
# Original: aaabbbbcc
# Compressed: a3b4c2
